# %% [markdown]
# <a href="https://colab.research.google.com/github/Raihandany/PCVK_Ganjil_2023/blob/main/Week1_PCVK_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
import matplotlib.pylab as plt

from google.colab.patches import cv2_imshow # for img display
from skimage import io
from skimage import transform
from PIL import Image

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
#medefinisikan tinggi dan lebar
tinggi = image_2.shape[0]
lebar  = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
from typing import final
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#menggunakan Looping
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

#tidak menggunakan perulangan "for"
image_3[int((tinggi)/2),:] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# Question
#
# 1.   Explain why in this Practicum module the execution of Python code is done using Google Colab ?
# 2.   Explain the use of each library in the eighth step practicum? Do all these libraries have to be used in this practical session
# 3.   In the 8th step of the experiance there is a snippet of the program code as follow :
# ```
# image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# ```
# What is the use of the program code ? and what is the effect if it is not done?
#
# 4.   Take a look at the following program code snippet :
# ```
# #membuat garis horizontal ditengah image
#   for y in range (tinggi):
#     image_3[y,int((lebar)/2)] = [255,255,255]
# ```
# What is the use of the code [255,255,255] ? Explain!
# 5.   Explain the relationship between pixels and high or low image resolution!

# %% [markdown]
# Answer
# 1.   Because the google colab is a IDE product like Jupyter hoted and have free space for junior programer/programmer to run their program, especially python program. In google colab all the python librari can be access freely but the user must have internet connection.
# 2.  I think all the libraries is importan in this practicum. cv2 is use to computer vision from our picture. pandas is use to  working with data sets. It has functions for analyzing, cleaning, exploring, and manipulating data. numpy use to input and add the collection of high-level mathematical functions. matplotlib is use to creating static, animated, and interactive visualizations in Python.
# - NumPy is a Python library used for working with arrays. It also has functions for working in domain of linear algebra, fourier transform, and matrices.
# - pandas is a software library written for the Python programming language for data manipulation and analysis, it offers data structures and operations for manipulating numerical tables and time series.
# - Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
#
# 3.   The program code is use to make a size of our picture, in this is code we make a frame size of our picture can fit in our screen. if we dont type this code the program will error and cannot progress well
# 4.   The code [255,255,255] is use to make color whit for our 3d picture, the first 255 is for red frame color, the second 255 is for green color and 255 the third is for blue color.
# 5.   The relation of the two is, if the picture have low resolution than the pixel can contain in picture is low too. And if the picture have high resolution the pixel that contain in picture is more/high too. Because pixel is 1 little frame inside picture.

# %%
from typing import final
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (tinggi):
  image_3[y,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
from typing import final
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#using looping
for y in range (tinggi)
  image_3[y,int(())]

#using cv.line
cv.line(image_3, (400,0), (0,286), [255,255,255], 1)

cv.line(image_3, (0,0), (400,286), [255,255,255], 1)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
from typing import final
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#using looping

#using cv
cv.line(image_3, (175,215), (295,215), [255,255,255], 1)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
from typing import final
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (110, 190):
    for x in range(165, 285):
        image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
