# %% [markdown]
# <a href="https://colab.research.google.com/github/Raihandany/PCVK_Ganjil_2023/blob/main/Week12_PCVK_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/PCVK_MM/prac_week12/haarcascades/haarcascade_frontalface_alt.xml')

jokowi_img = cv.imread('/content/drive/MyDrive/PCVK_MM/prac_week12/facedet/jokowi.jpg')
kartini_img = cv.imread('/content/drive/MyDrive/PCVK_MM/prac_week12/facedet/kartini.jpg')
kucing_img = cv.imread('/content/drive/MyDrive/PCVK_MM/prac_week12/facedet/kucing.jpg')
mask_img  = cv.imread('/content/drive/MyDrive/PCVK_MM/prac_week12/facedet/mask.png')
jordan_img  = cv.imread('/content/drive/MyDrive/PCVK_MM/prac_week12/facedet/mjordan.jpg')
people_img  = cv.imread('/content/drive/MyDrive/PCVK_MM/prac_week12/facedet/people.jpg')

# using array
# Create a list of images
images_arr = [jokowi_img, kartini_img, kucing_img, mask_img, jordan_img, people_img]
plt.figure(figsize = (15,5))

# Process each image separately
for i, img in enumerate(images_arr):
    # Convert the image to grayscale
    rgb_img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

    # Detect faces
    roi_wajah = cascade_wajah.detectMultiScale(rgb_img)

    # Draw rectangles around the faces
    for (x, y, w, h) in roi_wajah:
        cv.rectangle(img, (x, y), (x+w, y+h), (255, 255, 255), 3)

    # Plot the image
    plt.subplot(1, len(images_arr), i + 1)
    plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))  # Convert BGR to RGB for correct display
    plt.title(f'Image {i + 1}')

plt.show()

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/PCVK_MM/prac_week12/haarcascades/haarcascade_frontalface_alt.xml')

jokowi_img_detect = cv.imread('/content/drive/MyDrive/PCVK_MM/prac_week12/facedet/jokowi.jpg')
kartini_img_detect = cv.imread('/content/drive/MyDrive/PCVK_MM/prac_week12/facedet/kartini.jpg')
kucing_img_detect = cv.imread('/content/drive/MyDrive/PCVK_MM/prac_week12/facedet/kucing.jpg')
mask_img_detect  = cv.imread('/content/drive/MyDrive/PCVK_MM/prac_week12/facedet/mask.png')
jordan_img_detect  = cv.imread('/content/drive/MyDrive/PCVK_MM/prac_week12/facedet/mjordan.jpg')
people_img_detect  = cv.imread('/content/drive/MyDrive/PCVK_MM/prac_week12/facedet/people.jpg')


# Pak Jokowi Image
roi_wajah = cascade_wajah.detectMultiScale(jokowi_img_detect)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(jokowi_img_detect,(x,y),(x+w,y+h),(0,255,0),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(jokowi_img, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(jokowi_img, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(jokowi_img_detect, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(jokowi_img_detect, cv.COLOR_BGR2RGB))
plt.show()


# Bu Kartini Image
roi_wajah = cascade_wajah.detectMultiScale(kartini_img_detect)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(kartini_img_detect,(x,y),(x+w,y+h),(0,255,0),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(kartini_img, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(kartini_img, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(kartini_img_detect, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(kartini_img_detect, cv.COLOR_BGR2RGB))
plt.show()


# Kucing Image
roi_wajah = cascade_wajah.detectMultiScale(kucing_img_detect)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(kucing_img_detect,(x,y),(x+w,y+h),(0,255,0),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(kucing_img, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(kucing_img, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(kucing_img_detect, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(kucing_img_detect, cv.COLOR_BGR2RGB))
plt.show()


# Mask Image
roi_wajah = cascade_wajah.detectMultiScale(mask_img_detect)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(mask_img_detect,(x,y),(x+w,y+h),(0,255,0),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(mask_img, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(mask_img, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(mask_img_detect, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(mask_img_detect, cv.COLOR_BGR2RGB))
plt.show()


# Michael Jordan Image
roi_wajah = cascade_wajah.detectMultiScale(jordan_img_detect)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(jordan_img_detect,(x,y),(x+w,y+h),(0,255,0),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(jordan_img, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(jordan_img, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(jordan_img_detect, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(jordan_img_detect, cv.COLOR_BGR2RGB))
plt.show()


# People Image
roi_wajah = cascade_wajah.detectMultiScale(people_img_detect)
for(x,y,w,h) in roi_wajah:
 cv.rectangle(people_img_detect,(x,y),(x+w,y+h),(0,255,0),3)
plt.figure(figsize = (10,10))

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(people_img, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(people_img, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(cv.cvtColor(people_img_detect, cv.COLOR_BGR2RGB))
axarr[1].imshow(cv.cvtColor(people_img_detect, cv.COLOR_BGR2RGB))
plt.show()

# %%
kucing_img2 = cv.imread('/content/drive/MyDrive/PCVK_MM/prac_week12/facedet/kucing.jpg', 0)

cascade_kucing =  cv.CascadeClassifier(cv.data.haarcascades + 'haarcascade_frontalcatface.xml')

# Check if the image is loaded successfully
if kucing_img2 is None:
    print("Error: Image not loaded.")
else:
    kucing_img2 = cv.cvtColor(kucing_img2, cv.COLOR_GRAY2RGB)

    # Detect cat faces
    cat_faces = cascade_kucing.detectMultiScale(kucing_img2)

    # Draw rectangle around the cat faces
    for (x, y, w, h) in cat_faces:
        cv.rectangle(kucing_img2, (x, y), (x+w, y+h), (0, 255, 0), 2)

    # Display the output
    plt.subplot(121), plt.imshow(kucing_img2, cmap='gray')
    plt.title('Result'), plt.xticks([]), plt.yticks([])
    plt.show()

# %%
jokowi_img3 = cv.imread('/content/drive/MyDrive/PCVK_MM/prac_week12/facedet/jokowi.jpg')
jokowi_gray = cv.cvtColor(jokowi_img3, cv.COLOR_BGR2GRAY)
jokowi_img_gray_detect = cv.cvtColor(jokowi_img3, cv.COLOR_BGR2GRAY)

cascade_eye = cv.CascadeClassifier('/content/drive/MyDrive/PCVK_MM/prac_week12/haarcascades/haarcascade_eye.xml')

roi_eye = cascade_eye.detectMultiScale(jokowi_img_gray_detect)
for (x,y,w,h) in roi_eye:
  cv.rectangle(jokowi_img_gray_detect,(x,y),(x+w,y+h),(255,255,255),3)

# Plot outputs
f, axarr = plt. subplots(1,2,figsize=(15,15))
plt.subplot(121),plt.imshow(jokowi_gray, cmap='gray')
plt.subplot(122),plt.imshow(jokowi_img_gray_detect, cmap='gray')
plt.show()

# %%
# import dependencies
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time

# %%
# function to convert the JavaScript object into an OpenCV image
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# function to convert OpenCV Rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes

# %%
# initialize the Haar Cascade face detection model
face_cascade = cv2.CascadeClassifier(cv2.samples.findFile(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'))

# %%
def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);
const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)

  # get photo data
  data = eval_js('takePhoto({})'.format(quality))
  # get OpenCV format image
  img = js_to_image(data)
  # grayscale img
  gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
  print(gray.shape)
  # get face bounding box coordinates using Haar Cascade
  faces = face_cascade.detectMultiScale(gray)
  # draw face bounding box on image
  for (x,y,w,h) in faces:
      img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
  # save image
  cv2.imwrite(filename, img)

  return filename

# %%
try:
  filename = take_photo('photo.jpg')
  print('Saved to {}'.format(filename))

  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %%
mJordan = cv.imread('/content/drive/MyDrive/PCVK/Images/facedet/mjordan.jpg')
mJordan_gray = cv.cvtColor(mJordan, cv.COLOR_BGR2GRAY)
figure_size = 9

output = cv.medianBlur(mJordan_gray, figure_size)
f, axarr = plt. subplots(1,2,figsize=(15,15))
plt.subplot(121), plt.imshow(mJordan_gray, cmap='gray'),plt.title('Original')
plt.subplot(122), plt.imshow(output, cmap='gray'),plt.title('Median Filter')
plt.show()
